# %% [markdown]
# # Lab2 - Scikit-Learn

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library  
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

#import warnings library
import warnings
# ignore all warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 0. Loading Dataset

# %%
# read the data into datafram
data = pd.read_csv('breast_cancer.csv')

# %%
data.head()  # head method show only first 5 rows
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# feature names as a list
col = data.columns       # .columns gives columns names in data 
print(col)
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
# y includes our labels and x includes our features
y = data.diagnosis      # two labels: M = malignant, B = benign 

dropping_list = ['Unnamed: 32','id','diagnosis']
X = data.drop(dropping_list, axis = 1 )         # exclude three columns in X_feature matrix 
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
X.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
# split the dataset into training and testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ## 1. Supervised learning: classification

# %%
# you code here 
# 1. GaussianNB Classifier
from sklearn.naive_bayes import GaussianNB # import Gaussian Naive Bayes model
from sklearn.metrics import accuracy_score # import accuracy_score

clf = GaussianNB() # create Gaussian Naive Bayes classifier, clf is a classifier
clf.fit(X_train, y_train) # fit the classifier with training data, training data is X_train and y_train
y_pred = clf.predict(X_test) # do prediction on test data, X_test is test data, y_pred is predicted values, y_test is true values
accuracy = accuracy_score(y_test, y_pred) # get accuracy score, y_test is true values, y_pred is predicted values, accuracy is accuracy score
print(f'Prediction Accuracy: {accuracy:.2f}') # print accuracy score
# Out:
# Prediction Accuracy: 0.92

# %% [markdown]
# ## 2. Unsupervised learning: dimensionality

# %%
# you code here
# 2. PCA for Dimensionality Reduction
sns.set_style("darkgrid") # set the aesthetic style of the plots


pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X)
principal_df = pd.DataFrame(data=principalComponents, columns=['PCA1', 'PCA2'])

# Concatenate the target column 'diagnosis' with the principal components
final_df = pd.concat([principal_df, data[['diagnosis']]], axis=1)

# Scatter plot
colors = {'M':'blue', 'B':'orange'}
fig, ax = plt.subplots()
for diagnosis, color in colors.items():
    indices = final_df['diagnosis'] == diagnosis
    ax.scatter(final_df.loc[indices, 'PCA1'], final_df.loc[indices, 'PCA2'], c=color, label=diagnosis)

ax.set_xlabel('PCA1')
ax.set_ylabel('PCA2')
ax.set_xlim([-1000, 4000])
ax.set_ylim([-600, 800])
ax.grid(True)  # Add a grid
ax.set_aspect('auto')  # Set the x and y axes to the same scale
# Move the legend outside the box
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout()  # Adjusts subplot params for better layout
plt.scatter(final_df['PCA1'], final_df['PCA2'], c=final_df['diagnosis'].map(colors), alpha=0.5)

# %%
sns.set_style("darkgrid") # set the aesthetic style of the plots

pca = PCA(n_components=2) # create PCA with 2 components
principalComponents = pca.fit_transform(X) # fit the PCA with X, X is the data, principalComponents is the principal components, type is numpy array
principal_df = pd.DataFrame(data=principalComponents, columns=['PCA1', 'PCA2']) # create a pandas dataframe with principal components, principal_df is a pandas dataframe

final_df = pd.concat([principal_df, data[['diagnosis']]], axis=1) # Concatenate the target column 'diagnosis' with the principal components, final_df is a pandas dataframe

colors = {'M':'blue', 'B':'orange'} # create a dictionary with two colors, M is blue, B is orange
fig, ax = plt.subplots() # create a figure and a subplot, fig is the figure, ax is the subplot
for diagnosis, color in colors.items(): # iterate through the dictionary, diagnosis is key, color is value
    indices = final_df['diagnosis'] == diagnosis # get the indices of the diagnosis, diagnosis is key, indices is value, indices is a pandas series
    ax.scatter(final_df.loc[indices, 'PCA1'], final_df.loc[indices, 'PCA2'], c=color, label=diagnosis) # create scatter plot, x is PCA1, y is PCA2, c is color, label is diagnosis, indices is the indices of the diagnosis, diagnosis is key, indices is value, indices is a pandas series

ax.set_xlabel('PCA1') # set x label of the subplot
ax.set_ylabel('PCA2') # set y label of the subplot
ax.set_xlim([-1000, 4000]) # set x limit of the subplot
ax.set_ylim([-600, 800]) # set y limit of the subplot

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5)) # set legend location, so it is outside the box

sns.despine(offset=10, trim=True ) # add a dark border around the plot

plt.tight_layout()  # Adjusts subplot params for better layout
plt.show()

# %%
# 2. PCA for Dimensionality Reduction
pca = PCA(n_components=2) # create PCA with 2 components
principalComponents = pca.fit_transform(X) # fit the PCA with X, X is the data
principal_df = pd.DataFrame(data=principalComponents, columns=['PCA1', 'PCA2']) # create a dataframe with principal components

# Concatenate the target column 'diagnosis' with the principal components
final_df = pd.concat([principal_df, data[['diagnosis']]], axis=1) # concatenate the principal components with diagnosis column

# Scatter plot
colors = {'M':'blue', 'B':'orange'} # create a dictionary with two colors, M is blue, B is orange
fig, ax = plt.subplots() # create a figure and a subplot, fig is the figure, ax is the subplot
for diagnosis, color in colors.items(): # iterate through the dictionary, diagnosis is key, color is value
    indices = final_df['diagnosis'] == diagnosis # get the indices of the diagnosis, diagnosis is key, indices is value
    ax.scatter(final_df.loc[indices, 'PCA1'], final_df.loc[indices, 'PCA2'], c=color, label=diagnosis), # scatter plot, x is PCA1, y is PCA2, c is color, label is diagnosis, indices is the indices of the diagnosis, diagnosis is key, indices is value
# format the subplot
ax.set_xlabel('PCA1') # set x label
ax.set_ylabel('PCA2') # set y label
ax.set_xlim([-1000, 4000]) # set x limit
ax.set_ylim([-600, 800]) # set y limit
ax.grid(True)  # Add a grid
ax.grid(linestyle='-', linewidth='0.5', color='gray', visible='true')  # Customize the gridlines
# Move the legend outside the box
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5)) # set legend location

plt.tight_layout()  # Adjusts subplot params for better layout
plt.show() # show the plot
