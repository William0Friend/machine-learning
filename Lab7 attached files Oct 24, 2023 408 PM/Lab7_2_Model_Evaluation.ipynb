# %% [markdown]
# # Lab 7: Model Evaluation

# %%
import pandas as pd
import scipy as sp
import numpy as np
import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 0. Data Loading

# %%
#load data and extract data
names = ['age', 'workclass', 'fnlwgt', 'edu', 'edu-num', 'maritalstatus', 'occupation', 'relationship', 'race', 'sex','capital-gain','capital-loss','hours-per-week','native-country','income']
df = pd.read_csv('adult.data', names=names)
print( "Total columns: ", len(df.columns))
df.head()                 # display all columns
#df[df.columns[:5]].head() # display the first 5 columns
# Out:
# Total columns:  15
#    age          workclass  fnlwgt         edu  edu-num        maritalstatus  \
# 0   39          State-gov   77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors       13   Married-civ-spouse
# 2   38            Private  215646     HS-grad        9             Divorced
# 3   53            Private  234721        11th        7   Married-civ-spouse
# 4   28            Private  338409   Bachelors       13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week  native-country  income
# 0             0              40   United-States   <=50K
# 1             0              13   United-States   <=50K
# 2             0              40   United-States   <=50K
# 3             0              40   United-States   <=50K
# 4             0              40            Cuba   <=50K

# %%
from sklearn import preprocessing

# it is required that all feature/target values be numerical
# Systematically convert all string (labeled as object) type into labels(1,2,3,...)
label_encoding = preprocessing.LabelEncoder()
for column_name in df.columns:
    if df[column_name].dtype == object:
        df[column_name] = label_encoding.fit_transform(df[column_name])
    else:
        pass

# %%
# extract X, y
y = df['income']      # two labels: <=50K, >50K
X = df.drop('income', axis=1)

y.value_counts()
# Out:
# 0    24720
# 1     7841
# Name: income, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

print('Train/Test sizes:', y_train.shape[0], y_test.shape[0])
# Out:
# Train/Test sizes: 26048 6513

# %% [markdown]
# ## 1. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest_clf = RandomForestClassifier(n_estimators=50, random_state=1, n_jobs=-1)

# %% [markdown]
# ## 2 Confusion matrix, precision, recall, f1-score, accuracy

# %%
# use 3-fold cross validation to predict y labels on the training dataset
# the predicted labels should be used 
from sklearn.model_selection import cross_val_predict
y_train_pred = cross_val_predict(random_forest_clf, X_train, y_train, cv=3)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# your code below for confusion matrix, precision, recall, f1-score, accuracy
# start of your code (don't modify code outside your code block)
# Calculate confusion matrix
cm = confusion_matrix(y_train, y_train_pred)

# Calculate precision, recall, f1-score, and accuracy
precision = precision_score(y_train, y_train_pred)
recall = recall_score(y_train, y_train_pred)
f1 = f1_score(y_train, y_train_pred)
accuracy = accuracy_score(y_train, y_train_pred)

print("Confusion Matrix:\n", cm)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)




# end of your code (don't modify code outside your code block)

# %% [markdown]
# ## 3 ROC curve and AUC score

# %%
import matplotlib.pyplot as plt
def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0,1], [0,1], 'k--', label='Random')
    plt.grid()
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend(loc='lower right')
    plt.show()

# %%
# use 3-fold cross validation to predict y probabilities (for each class) on the training dataset
y_train_prob = cross_val_predict(random_forest_clf, X_train, y_train, cv=3, method="predict_proba")

#Important: 
# y_train_prob is numpy 2-d array, where each row is the predicted probablities for each class
# in this dataset we have two classes (<=50K, and >50K), so we have two probability scores
# e.g., the first row (0.76, 0.24) means the probability predicting <=50K is .76, 
#       and the probability predicting >50K is .24, 
#       for ROC curve and score calculation, we only need the second column as our predicted scores
y_train_prob[:3]
# Out:
# array([[0.76, 0.24],
#        [0.28, 0.72],
#        [0.12, 0.88]])

# %%
from sklearn.metrics import roc_curve

# your code below for roc_curve (i.e., display roc plot)

# start of your code (don't modify code outside your code block)

# Extract only the probabilities of the positive class
y_scores = y_train_prob[:, 1]

# Calculate the ROC curve values
fpr, tpr, thresholds = roc_curve(y_train, y_scores)

# Plot the ROC curve
plot_roc_curve(fpr, tpr)

# display roc plot



# end of your code (don't modify code outside your code block)

# %%
from sklearn.metrics import roc_auc_score

# your code below for auc score
# start of your code (don't modify code outside your code block)


# Calculate AUC score
auc_score = roc_auc_score(y_train, y_scores)
print("AUC Score:", auc_score)




# end of your code (don't modify code outside your code block)
# Out:
# AUC Score: 0.9016549964536094

# %% [markdown]
# ## 4 Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
# your code below for setting up grid search score

# Define the parameters for Grid Search
param_grid = {
    'max_depth': [80, 90, 100],
    'max_features': [1, 2, 3],
    'min_samples_leaf': [2, 3, 4],
    'n_estimators': [100, 300, 1000, 1200]
}

# Set up the Grid Search with the random forest classifier
grid_search = GridSearchCV(estimator=random_forest_clf, param_grid=param_grid, 
                           cv=3, n_jobs=-1, verbose=2)

# Fit the model with the parameters specified
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# [CV] END max_depth=80, max_features=1, min_samples_leaf=2, n_estimators=100; total time=   2.0s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=2, n_estimators=100; total time=   2.3s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=2, n_estimators=300; total time=   6.1s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=2, n_estimators=300; total time=   6.0s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=2, n_estimators=300; total time=   6.5s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=3, n_estimators=100; total time=   2.6s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=3, n_estimators=100; total time=   2.2s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=3, n_estimators=100; total time=   3.3s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=3, n_estimators=300; total time=   7.0s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=3, n_estimators=300; total time=   7.4s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=3, n_estimators=300; total time=   6.6s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=2, n_estimators=1000; total time=  23.3s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=2, n_estimators=1000; total time=  23.3s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=2, n_estimators=1000; total time=  22.6s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=2, n_estimators=1200; total time=  23.6s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=2, n_estimators=1200; total time=  28.2s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=2, n_estimators=1200; total time=  28.2s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=4, n_estimators=100; total time=   2.6s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=4, n_estimators=100; total time=   2.3s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=4, n_estimators=100; total time=   2.5s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=3, n_estimators=1000; total time=  20.1s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=4, n_estimators=300; total time=   7.1s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=3, n_estimators=1000; total time=  20.3s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=4, n_estimators=300; total time=   7.5s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=3, n_estimators=1000; total time=  22.3s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=4, n_estimators=300; total time=   6.1s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=3, n_estimators=1200; total time=  23.7s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=3, n_estimators=1200; total time=  24.8s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=2, n_estimators=100; total time=   2.8s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=3, n_estimators=1200; total time=  24.3s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=2, n_estimators=100; total time=   3.2s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=2, n_estimators=100; total time=   3.0s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=4, n_estimators=1000; total time=  19.5s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=4, n_estimators=1000; total time=  18.9s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=2, n_estimators=300; total time=   7.8s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=4, n_estimators=1000; total time=  19.6s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=2, n_estimators=300; total time=   7.9s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=2, n_estimators=300; total time=   8.4s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=4, n_estimators=1200; total time=  22.9s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=4, n_estimators=1200; total time=  23.3s
# [CV] END max_depth=80, max_features=1, min_samples_leaf=4, n_estimators=1200; total time=  24.1s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   4.2s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   3.2s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   3.5s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, n_estimators=300; total time=  21.4s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, n_estimators=300; total time=  21.8s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=2, n_estimators=1000; total time=  41.2s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=2, n_estimators=1000; total time=  41.4s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=2, n_estimators=1000; total time=  42.8s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, n_estimators=300; total time=   8.0s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=2, n_estimators=1200; total time=  49.0s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=2, n_estimators=1200; total time=  48.1s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=2, n_estimators=1200; total time=  49.0s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=4, n_estimators=100; total time=   3.9s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=4, n_estimators=100; total time=   3.6s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=4, n_estimators=100; total time=   4.4s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, n_estimators=1000; total time=  31.8s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=4, n_estimators=300; total time=  11.1s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=4, n_estimators=300; total time=  10.7s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, n_estimators=1000; total time=  33.6s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, n_estimators=1000; total time=  36.6s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=4, n_estimators=300; total time=  10.3s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, n_estimators=1200; total time=  41.3s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, n_estimators=1200; total time=  43.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, n_estimators=100; total time=   5.5s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, n_estimators=1200; total time=  41.5s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, n_estimators=100; total time=   5.7s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, n_estimators=100; total time=   5.1s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=4, n_estimators=1000; total time=  36.0s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=4, n_estimators=1000; total time=  36.3s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=4, n_estimators=1000; total time=  37.9s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, n_estimators=300; total time=  12.9s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, n_estimators=300; total time=  14.9s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, n_estimators=300; total time=  13.1s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=4, n_estimators=1200; total time=  43.3s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=4, n_estimators=1200; total time=  43.6s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=3, n_estimators=100; total time=   5.8s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=4, n_estimators=1200; total time=  46.2s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=3, n_estimators=100; total time=   4.4s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=3, n_estimators=100; total time=   4.8s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=3, n_estimators=300; total time=  15.0s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=3, n_estimators=300; total time=  16.4s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, n_estimators=1000; total time=  45.6s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, n_estimators=1000; total time=  47.3s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, n_estimators=1000; total time=  48.7s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=3, n_estimators=300; total time=  13.9s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, n_estimators=1200; total time=  59.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, n_estimators=1200; total time=  58.6s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, n_estimators=1200; total time=  57.0s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, n_estimators=100; total time=   5.0s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, n_estimators=100; total time=   5.3s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, n_estimators=100; total time=   5.7s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=3, n_estimators=1000; total time=  45.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, n_estimators=300; total time=  14.3s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, n_estimators=300; total time=  15.0s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=3, n_estimators=1000; total time=  47.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=3, n_estimators=1000; total time=  48.9s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, n_estimators=300; total time=  14.7s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=3, n_estimators=1200; total time=  54.8s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=3, n_estimators=1200; total time=  56.6s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, n_estimators=100; total time=   4.4s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, n_estimators=100; total time=   3.6s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=3, n_estimators=1200; total time=  55.4s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, n_estimators=100; total time=   4.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, n_estimators=300; total time=  12.1s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, n_estimators=300; total time=  11.7s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, n_estimators=1000; total time=  43.9s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, n_estimators=1000; total time=  43.8s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, n_estimators=1000; total time=  44.3s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, n_estimators=300; total time=  10.6s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, n_estimators=1200; total time=  52.9s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, n_estimators=1200; total time=  50.6s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, n_estimators=1200; total time=  55.2s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=3, n_estimators=100; total time=   3.7s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=3, n_estimators=100; total time=   3.9s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=3, n_estimators=100; total time=   3.5s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, n_estimators=1000; total time=  32.7s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, n_estimators=1000; total time=  33.4s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, n_estimators=1000; total time=  32.7s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=3, n_estimators=300; total time=  10.1s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=3, n_estimators=300; total time=   8.7s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=3, n_estimators=300; total time=   9.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, n_estimators=1200; total time=  37.0s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, n_estimators=1200; total time=  36.1s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, n_estimators=100; total time=   3.2s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, n_estimators=100; total time=   3.7s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, n_estimators=100; total time=   3.4s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=2, n_estimators=1200; total time=  37.5s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=3, n_estimators=1000; total time=  28.2s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, n_estimators=300; total time=   9.3s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, n_estimators=300; total time=   7.9s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=3, n_estimators=1000; total time=  26.9s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=3, n_estimators=1000; total time=  29.6s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, n_estimators=300; total time=   8.6s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=3, n_estimators=1200; total time=  33.7s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=3, n_estimators=1200; total time=  34.4s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=3, n_estimators=1200; total time=  34.4s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=2, n_estimators=100; total time=   4.0s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=2, n_estimators=100; total time=   4.4s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=2, n_estimators=100; total time=   4.5s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, n_estimators=1000; total time=  27.9s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, n_estimators=1000; total time=  28.4s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, n_estimators=1000; total time=  27.2s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=2, n_estimators=300; total time=  11.0s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=2, n_estimators=300; total time=  11.9s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, n_estimators=1200; total time=  33.6s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=2, n_estimators=300; total time=  11.7s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, n_estimators=1200; total time=  32.2s
# [CV] END max_depth=90, max_features=1, min_samples_leaf=4, n_estimators=1200; total time=  32.8s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   4.5s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   5.2s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   4.8s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=3, n_estimators=300; total time=  12.8s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=3, n_estimators=300; total time=  13.6s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=2, n_estimators=1000; total time=  37.4s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=2, n_estimators=1000; total time=  39.1s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=2, n_estimators=1000; total time=  38.5s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=3, n_estimators=300; total time=  12.0s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=2, n_estimators=1200; total time=  47.1s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=2, n_estimators=1200; total time=  45.6s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=2, n_estimators=1200; total time=  46.9s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=4, n_estimators=100; total time=   4.4s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=4, n_estimators=100; total time=   5.1s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=4, n_estimators=100; total time=   4.7s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=3, n_estimators=1000; total time=  35.8s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=4, n_estimators=300; total time=  10.4s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=3, n_estimators=1000; total time=  37.7s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=3, n_estimators=1000; total time=  35.6s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=4, n_estimators=300; total time=  11.3s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=4, n_estimators=300; total time=  10.7s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=3, n_estimators=1200; total time=  45.4s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=3, n_estimators=1200; total time=  45.6s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=2, n_estimators=100; total time=   5.0s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=3, n_estimators=1200; total time=  46.1s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=2, n_estimators=100; total time=   4.6s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=2, n_estimators=100; total time=   5.7s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=4, n_estimators=1000; total time=  36.2s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=4, n_estimators=1000; total time=  35.6s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=4, n_estimators=1000; total time=  35.8s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=2, n_estimators=300; total time=  15.0s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=2, n_estimators=300; total time=  15.2s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=4, n_estimators=1200; total time=  45.0s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=2, n_estimators=300; total time=  13.7s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=4, n_estimators=1200; total time=  45.5s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=3, n_estimators=100; total time=   6.2s
# [CV] END max_depth=90, max_features=2, min_samples_leaf=4, n_estimators=1200; total time=  46.9s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=3, n_estimators=100; total time=   5.6s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=3, n_estimators=100; total time=   5.9s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=3, n_estimators=300; total time=  15.2s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=3, n_estimators=300; total time=  16.2s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=2, n_estimators=1000; total time=  45.8s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=2, n_estimators=1000; total time=  45.8s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=2, n_estimators=1000; total time=  45.0s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=3, n_estimators=300; total time=  13.6s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=2, n_estimators=1200; total time=  56.7s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=2, n_estimators=1200; total time=  58.5s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=2, n_estimators=1200; total time=  58.8s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=4, n_estimators=100; total time=   4.3s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=4, n_estimators=100; total time=   5.5s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=4, n_estimators=100; total time=   5.4s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=4, n_estimators=300; total time=  14.0s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=3, n_estimators=1000; total time=  51.8s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=4, n_estimators=300; total time=  17.0s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=3, n_estimators=1000; total time=  50.3s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=3, n_estimators=1000; total time=  51.0s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=4, n_estimators=300; total time=  16.1s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=3, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=90, max_features=3, min_samples_leaf=3, n_estimators=1200; total time=  58.1s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=2, n_estimators=100; total time=   4.0s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=3, n_estimators=1200; total time=  55.6s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=2, n_estimators=100; total time=   3.5s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=2, n_estimators=100; total time=   3.8s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=2, n_estimators=300; total time=  11.5s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=2, n_estimators=300; total time=  10.4s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=4, n_estimators=1000; total time=  44.8s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=4, n_estimators=1000; total time=  46.9s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=2, n_estimators=300; total time=  10.3s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=4, n_estimators=1000; total time=  49.3s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=4, n_estimators=1200; total time=  55.6s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=4, n_estimators=1200; total time=  55.0s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=3, n_estimators=100; total time=   4.4s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=2, n_estimators=1000; total time=  32.0s
# [CV] END max_depth=90, max_features=3, min_samples_leaf=4, n_estimators=1200; total time=  56.3s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=3, n_estimators=100; total time=   3.2s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=3, n_estimators=100; total time=   3.7s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=2, n_estimators=1000; total time=  31.9s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=2, n_estimators=1000; total time=  34.3s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=3, n_estimators=300; total time=   7.9s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=3, n_estimators=300; total time=   9.1s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=3, n_estimators=300; total time=   9.0s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=2, n_estimators=1200; total time=  36.5s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=2, n_estimators=1200; total time=  36.4s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=4, n_estimators=100; total time=   3.3s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=4, n_estimators=100; total time=   3.5s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=2, n_estimators=1200; total time=  37.1s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=4, n_estimators=100; total time=   3.6s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=4, n_estimators=300; total time=   8.9s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=4, n_estimators=300; total time=   8.0s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=3, n_estimators=1000; total time=  29.5s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=3, n_estimators=1000; total time=  28.1s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=3, n_estimators=1000; total time=  30.8s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=4, n_estimators=300; total time=   8.9s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=3, n_estimators=1200; total time=  33.9s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=3, n_estimators=1200; total time=  35.3s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=3, n_estimators=1200; total time=  34.6s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=2, n_estimators=100; total time=   5.0s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=2, n_estimators=100; total time=   5.1s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=2, n_estimators=100; total time=   5.2s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=4, n_estimators=1000; total time=  27.7s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=4, n_estimators=1000; total time=  28.6s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=2, n_estimators=300; total time=  13.0s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=4, n_estimators=1000; total time=  30.5s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=2, n_estimators=300; total time=  14.1s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=4, n_estimators=1200; total time=  34.4s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=4, n_estimators=1200; total time=  34.4s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=2, n_estimators=300; total time=  13.6s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   5.1s
# [CV] END max_depth=100, max_features=1, min_samples_leaf=4, n_estimators=1200; total time=  37.0s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   4.9s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   4.8s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=3, n_estimators=300; total time=  14.4s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=3, n_estimators=300; total time=  14.7s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=2, n_estimators=1000; total time=  42.6s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=2, n_estimators=1000; total time=  44.4s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=3, n_estimators=300; total time=  12.4s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=2, n_estimators=1000; total time=  43.9s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=2, n_estimators=1200; total time=  55.1s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=2, n_estimators=1200; total time=  52.2s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=2, n_estimators=1200; total time=  55.8s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=4, n_estimators=100; total time=   5.1s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=4, n_estimators=100; total time=   4.4s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=4, n_estimators=100; total time=   4.2s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=3, n_estimators=1000; total time=  39.4s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=4, n_estimators=300; total time=  10.7s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=3, n_estimators=1000; total time=  38.6s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=4, n_estimators=300; total time=  12.3s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=3, n_estimators=1000; total time=  40.1s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=4, n_estimators=300; total time=  13.5s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=3, n_estimators=1200; total time=  48.5s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=3, n_estimators=1200; total time=  50.6s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=2, n_estimators=100; total time=   6.3s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=2, n_estimators=100; total time=   5.7s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=3, n_estimators=1200; total time=  49.3s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=2, n_estimators=100; total time=   6.7s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=4, n_estimators=1000; total time=  37.3s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=4, n_estimators=1000; total time=  41.1s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=4, n_estimators=1000; total time=  40.6s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=2, n_estimators=300; total time=  17.9s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=2, n_estimators=300; total time=  15.5s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=2, n_estimators=300; total time=  15.2s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=4, n_estimators=1200; total time=  50.5s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=4, n_estimators=1200; total time=  46.4s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=3, n_estimators=100; total time=   5.6s
# [CV] END max_depth=100, max_features=2, min_samples_leaf=4, n_estimators=1200; total time=  48.1s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=3, n_estimators=100; total time=   6.2s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=3, n_estimators=100; total time=   6.0s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=3, n_estimators=300; total time=  14.1s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=3, n_estimators=300; total time=  17.3s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=2, n_estimators=1000; total time=  49.5s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=2, n_estimators=1000; total time=  55.1s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=3, n_estimators=300; total time=  15.5s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=2, n_estimators=1000; total time=  51.7s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=2, n_estimators=1200; total time= 1.0min
# [CV] END max_depth=100, max_features=3, min_samples_leaf=2, n_estimators=1200; total time=  59.5s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=4, n_estimators=100; total time=   5.3s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=2, n_estimators=1200; total time= 1.1min
# [CV] END max_depth=100, max_features=3, min_samples_leaf=4, n_estimators=100; total time=   5.1s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=4, n_estimators=100; total time=   5.5s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=3, n_estimators=1000; total time=  48.1s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=4, n_estimators=300; total time=  16.9s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=3, n_estimators=1000; total time=  47.6s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=4, n_estimators=300; total time=  14.5s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=3, n_estimators=1000; total time=  50.5s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=4, n_estimators=300; total time=  14.7s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=3, n_estimators=1200; total time=  58.1s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=3, n_estimators=1200; total time=  57.4s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=3, n_estimators=1200; total time=  56.0s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=4, n_estimators=1000; total time=  40.7s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=4, n_estimators=1000; total time=  42.5s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=4, n_estimators=1000; total time=  42.3s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=4, n_estimators=1200; total time=  44.5s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=4, n_estimators=1200; total time=  35.2s
# [CV] END max_depth=100, max_features=3, min_samples_leaf=4, n_estimators=1200; total time=  40.7s
# GridSearchCV(cv=3,
#              estimator=RandomForestClassifier(n_estimators=50, n_jobs=-1,
#                                               random_state=1),
#              n_jobs=-1,
#              param_grid={'max_depth': [80, 90, 100], 'max_features': [1, 2, 3],
#                          'min_samples_leaf': [2, 3, 4],
#                          'n_estimators': [100, 300, 1000, 1200]},
#              verbose=2)

# %%
# your code below for print out the best parameters and best score
# Print the best parameters and their corresponding accuracy score
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'max_depth': 80, 'max_features': 2, 'min_samples_leaf': 3, 'n_estimators': 300}
# Best Score: 0.8639433883172472
